# %%
# Body mass index (BMI)
# Input weight
# Height
# Ask yourself your height 
# Weight
# Calculate BMI 
# Print BMI (My name is "this", and my BMI IS : "this")

# %%
# name = input("What is your name: ")
# weight = float(input("Enter your weight in kg: "))
# height = float(input("Enter your height in meters: "))

# BMI = weight / (height * height)
# print("Hi! " + name, "your BMI is: ", BMI)
# Out:
# What is your name:  Tauha
# Enter your weight in kg:  58
# Enter your height in meters:  1.5
# Hi! Tauha your BMI is:  25.77777777777778

# %%
name = input("What is your name: ")
weight = input("Enter your weight in kg: ")
height = input("Enter your height in meters: ")

weight = float(weight)
height = float(height)

BMI = weight / (height * height)
print("Hi! " + name, "your BMI is: ", BMI)
# Out:
# What is your name:  t
# Enter your weight in kg:  34
# Enter your height in meters:  234
# Hi! t your BMI is:  0.0006209365183724158

# %% [markdown]
# # Making a Barplot

# %%
# Run in vscode
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.laod_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 6
#       3 import matplotlib.pyplot as plt
#       4 sns.set_theme(style="ticks", color_codes=True)
# ----> 6 titanic = sns.laod_dataset("titanic")
#       7 sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
#       8 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'laod_dataset'
