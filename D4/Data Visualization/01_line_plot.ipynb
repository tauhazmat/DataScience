# %% [markdown]
# # Import libraries
# - Seaborn automatically installs these libraries
# - *numpy*
# - *scipy*
# - *pandas*
# - *matplotlib*

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
flower = sns.load_dataset("iris")
flower

# draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Adding Title

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
flower = sns.load_dataset("iris")
flower

# draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.title("Iris flower data")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Adding limits

# %%
# import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
flower = sns.load_dataset("iris")
flower

# draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.title("Iris flower data")
plt.xlim(2)
plt.ylim(1)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
import seaborn as sns  # Uncommented the seaborn import
import matplotlib.pyplot as plt

# load dataset
flower = sns.load_dataset("iris")
flower

# draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.title("Iris flower data")
sns.set_theme(style="dark")  # Changed "dark" to style="dark" - using style parameter instead of context

# %% [markdown]
# # Size of Figure

# %%
import matplotlib.pyplot as plt

# load dataset
flower = sns.load_dataset("iris")

# change figure
plt.figure(figsize=(8,6))

# draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.title("Iris flower data")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
