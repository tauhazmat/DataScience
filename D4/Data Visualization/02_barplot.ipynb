# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
flower = sns.load_dataset("iris")
flower

# draw a barplot
sns.barplot(x="species", y="sepal_width", data=flower)
plt.show()

# %%
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
flower = sns.load_dataset("iris")
flower

# draw a barplot
sns.barplot(x="species", y="petal_length", data=flower)
plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
cruise = sns.load_dataset("titanic")
cruise
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
cruise = sns.load_dataset("titanic")
cruise

sns.barplot(x="sex", y="alone",hue="who", data=cruise)
plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
cruise = sns.load_dataset("titanic")
cruise

sns.barplot(x="sex", y="alone",hue="who", data=cruise, order=["female", "male"])
plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
cruise = sns.load_dataset("titanic")
cruise

sns.barplot(x="sex", y="alone",hue="who", data=cruise, order=["female", "male"], color="red", palette="pastel")
plt.show()

# %%
# import libraries
import seaborn as sns
# from numpy import median, mean
import numpy
import matplotlib.pyplot as plt

# load dataset
cruise = sns.load_dataset("titanic")
cruise

sns.barplot(x="class", y="fare",hue="sex", data=cruise, estimator=median)
plt.show()

# %%
# import libraries
import seaborn as sns
# from numpy import median, mean
import numpy
import matplotlib.pyplot as plt

# load dataset
cruise = sns.load_dataset("titanic")
cruise

sns.barplot(x="class", y="fare",hue="sex", data=cruise, estimator=median, saturation=0.5, color="red")
plt.show()
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_9500\3430956654.py:11: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(x="class", y="fare",hue="sex", data=cruise, estimator=median, saturation=0.5, color="red")

# %%
# Horizontal plot
# import libraries
import seaborn as sns
# from numpy import median, mean
import numpy
import matplotlib.pyplot as plt

# load dataset
cruise = sns.load_dataset("titanic")
cruise

sns.barplot(x="fare", y="class",hue="sex", data=cruise, estimator=median, saturation=1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# read a titanic.csv file
# from seaborn library
cruise = sns.load_dataset("titanic")

sns.barplot(x="class", y="fare", data=cruise,
                linewidth=5, facecolor=(0.1, 0.3, 0.3, 0.5),
                errcolor=".2", edgecolor=".2")
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_3656\2365074500.py:8: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '.2'}` instead.
#
#   sns.barplot(x="class", y="fare", data=cruise,
# <Axes: xlabel='class', ylabel='fare'>
